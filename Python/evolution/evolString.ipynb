# %%
import random
import string

# %%
# Our target — what we're trying to evolve toward
TARGET = "Sultans of swing"

# The alphabet our random strings can use
ALPHABET = string.ascii_lowercase + " "

def random_individual():
    """Create a random string the same length as TARGET."""
    return ''.join(random.choice(ALPHABET) for _ in range(len(TARGET)))

def fitness(individual):
    """Count how many characters match the target."""
    return sum(a == b for a, b in zip(individual, TARGET))

# Create a small population and score them
population = [random_individual() for _ in range(10)]

for p in population:
    print(f"{p}  |  fitness: {fitness(p)}/{len(TARGET)}")
# Out:
# zppwseqxbf vstoi  |  fitness: 2/16
# hshtclfshnqmevjf  |  fitness: 1/16
# gzqzamimkcgaigxg  |  fitness: 2/16
# ofgfsfuvwtioamhd  |  fitness: 0/16
# dqofwghheynhbpuk  |  fitness: 0/16
# seyoxzbmwaoorhnp  |  fitness: 1/16
# jrqgdttmkpsyhneu  |  fitness: 0/16
# qyfgyghic cyhuaa  |  fitness: 0/16
# gguffvquxwoywzmi  |  fitness: 1/16
# wi yplnhkbyrjcau  |  fitness: 0/16

# %%
# How far apart are two characters?
print(ord('h') - ord('g'))  # what do you get?
print(ord('h') - ord('z'))  # and this?
print(abs(ord('h') - ord('z')))  # why abs?
# Out:
# 1
# -18
# 18

# %%
test = "ulf"

guess = "str"

distances = [abs(ord(a) - ord(b)) for a,b in zip(test, guess)]

print(sum(distances))

def distanceFitness(input, target):
    distances = [abs(ord(a) - ord(b)) for a,b in zip(input, target)]
    return sum(distances)



print(distanceFitness("hello world", "hello world"))  # should be?
print(distanceFitness("gello world", "hello world"))  # one letter off by 1
print(distanceFitness("zzzzzzzzzzz", "hello world"))  # garbage
# Out:
# 22
# 0
# 1
# 226

# %%
population = [random_individual() for _ in range(10)]



scored = [(individual, distanceFitness(individual, TARGET)) for individual in population]

[print(a) for a in scored]

print("sorted")
sorted_scored = sorted(scored, key = lambda x: x[1])

[print(a) for a in sorted_scored]
# Out:
# ('bmrzgvwgvpdrglgo', 244)
# ('airdajgllgqkdyfi', 278)
# ('jtqcxvdgrgrplgme', 268)
# ('uafduznlkilzzega', 299)
# ('duhshnppooevnwn ', 287)
# (' uzvwkaw gbejaeb', 392)
# ('dlvllovktomuqn f', 317)
# ('itipkpgjkgqnlcmf', 238)
# ('abdrevieyaspbtuf', 275)
# ('zrofvfjhgkfshf z', 367)
# sorted
# ('itipkpgjkgqnlcmf', 238)
# ('bmrzgvwgvpdrglgo', 244)
# ('jtqcxvdgrgrplgme', 268)
# ('abdrevieyaspbtuf', 275)
# ('airdajgllgqkdyfi', 278)
# ('duhshnppooevnwn ', 287)
# ('uafduznlkilzzega', 299)
# ('dlvllovktomuqn f', 317)
# ('zrofvfjhgkfshf z', 367)
# (' uzvwkaw gbejaeb', 392)
# [None, None, None, None, None, None, None, None, None, None]

# %%
def crossover(parent_a, parent_b):
    splitPoint = random.randint(0, len(parent_a)-1)
    result = parent_a[:splitPoint] + parent_b[splitPoint:]
    return result

def mutate(input, chance):
    output = ""
    for a in input:
        mutate_choice = random.randint(1, 100)
        if mutate_choice <= chance:
            output += random.choice(ALPHABET)
        else:
            output += a
    return output

# %%
for _ in range(5):
    print(crossover("ebweofijrbj", "gehvnvyzwot"))
# Out:
# ebwenvyzwot
# ebwenvyzwot
# ebweofijrot
# ebweofizwot
# ebweofijrot

# %%
population = [random_individual() for _ in range(100)]

for a in range(200):
    children = []
    mutated_children = []
    scored = [(individual, distanceFitness(individual, TARGET)) for individual in population]
    sorted_scored = sorted(scored, key = lambda x: x[1])
    kept = sorted_scored[:20]
    for i in range(0, len(kept)-1, 2):
        a = kept[i]
        b = kept[i+1]
        child = crossover(a[0], b[0])
        child2 = crossover(a[0], b[0])
        children.append(child)
        children.append(child2)
    for i in children:
        mutated_children.append(mutate(i,10))
    population = []
    population = [item[0] for item in kept] + mutated_children




[print(a)for a in population]
# Out:
# aumtans of swing
# aumtans of swing
# aumtans of swing
# aumtans of swing
# aumtans of swing
# aumtans of swing
# aumtans of swing
# aumtans of swing
# aumtans of swing
# aumtans of swing
# aumtans of swing
# aumtans of swing
# aumtans of swing
# aumtans of swing
# aumtans of swing
# aumtans of swing
# aumtans of swing
# aumtans of swing
# aumtans of swing
# aumtans of swing
# aumtans of swing
# aumtafs of swing
# aqmtbns of swing
# kumtans of swing
# au tans of swiny
# yumtans of swing
# dumqvns ofrswing
# aumwans of swing
#  umtans ofoswing
# auoeans xf swing
# aumtans nf swing
# anmtani ok swing
# aumtans of swing
# aumtans of bwnng
# aumtans oy swing
# uumtjnw of swing
# aujtans of xwing
# aumtans of swigg
# aumtans of swing
# aumtans of swing
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]
