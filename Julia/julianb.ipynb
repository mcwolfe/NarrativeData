# %%
x = 10
y = 20
z = x + y
println("The sum of x and y is: ", z)
# Out:
# The sum of x and y is: 30

# %%
function greet(name)
    return "Hello, " * name * "!"
end

message = greet("Colaboratory")
println(message)
# Out:
# Hello, Colaboratory!
